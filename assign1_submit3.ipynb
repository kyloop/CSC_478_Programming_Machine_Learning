# %% [markdown]
# Name: Kai Chung, Ying
#
# Class: CSC 478
# Assignment #1
#
# Date: 09/28/2017

# %% [markdown]
# #The first couple steps is the Data Preparation and Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read the csv file to Pandas DataFrame format with column 'ID' as index
bank_df=pd.read_csv('bank_data.csv',sep=',',index_col='id')

# %%
#Check the number of records in the Table
bank_df.shape
# Out:
# (600, 11)

# %%
#Check the top 5 lines of the D.F.
bank_df.head(5)
# Out:
#          age   income  children  gender      region married  car savings_acct  \
# id
# ID12101   48  17546.0         1  FEMALE  INNER_CITY      NO   NO           NO
# ID12102   40  30085.1         3    MALE        TOWN     YES  YES           NO
# ID12103   51  16575.4         0  FEMALE  INNER_CITY     YES  YES          YES
# ID12104   23  20375.4         3  FEMALE        TOWN     YES   NO           NO
# ID12105   57  50576.3         0  FEMALE       RURAL     YES   NO          YES
#
#         current_acct mortgage  pep
# id
# ID12101           NO       NO  YES
# ID12102          YES      YES   NO
# ID12103          YES       NO   NO
# ID12104          YES       NO   NO
# ID12105           NO       NO   NO

# %% [markdown]
# #1.)Explore the general characteristics of the data as a whole: examine the means, standard deviations, and other statistics associated with the numerical attributes; show the distributions of values associated with categorical attributes; etc.
#
# Ans:
# Based on the following result, the total count of records is 600.
#
# The mean value of age is 42.295 with standard deviation 14.425. The range of age is between 18.0 and 67.0. The median value is 42.0. The interquartile (IQR) of age is 25.25 with 1st Quartile (25% Percetile) 30.0 and 3rd Quartile (75% percentile) 55.25.
#
# The mean value of income is 27524.031 with standard deviation 12899.468. The range of age is between 5014.21 and 63130.1. The median value is 24925.3. The interquartile (IQR) of age is 18908.175 with 1st Quartile (25% Percetile) 17264.5 and 3rd Quartile (75% percentile) 36172.675.
#
# The mean value of children is 1.012 with standard deviation 1.057. The range of age is between 0.00 and 3.0. The median value is 1.0. The interquartile (IQR) of age is 2.0 with 1st Quartile (25% Percetile) 0.0 and 3rd Quartile (75% percentile) 2.0.

# %%
#Examine the statistics associated with the numerical attributes
bank_df.describe()
# Out:
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %%
#Examine the statistics of ALL attributes
bank_df.describe(include='all')
# Out:
#                age        income    children  gender      region married  car  \
# count   600.000000    600.000000  600.000000     600         600     600  600
# unique         NaN           NaN         NaN       2           4       2    2
# top            NaN           NaN         NaN  FEMALE  INNER_CITY     YES   NO
# freq           NaN           NaN         NaN     300         269     396  304
# mean     42.395000  27524.031217    1.011667     NaN         NaN     NaN  NaN
# std      14.424947  12899.468246    1.056752     NaN         NaN     NaN  NaN
# min      18.000000   5014.210000    0.000000     NaN         NaN     NaN  NaN
# 25%      30.000000  17264.500000    0.000000     NaN         NaN     NaN  NaN
# 50%      42.000000  24925.300000    1.000000     NaN         NaN     NaN  NaN
# 75%      55.250000  36172.675000    2.000000     NaN         NaN     NaN  NaN
# max      67.000000  63130.100000    3.000000     NaN         NaN     NaN  NaN
#
# ...

# %% [markdown]
# Based on the above, we could observe that there are "NaN" shown on the Table which means those Categorical attributes statistics are NOT computable.

# %%
#Check the columns attributes title
bank_df.columns
# Out:
# Index(['age', 'income', 'children', 'gender', 'region', 'married', 'car',
#        'savings_acct', 'current_acct', 'mortgage', 'pep'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20, 120))
# Create an Axes object.

ax1 = fig.add_subplot(8,2,1) # one row, two column, first plot
# Plot the data.
bank_df['gender'].value_counts().plot(kind='bar')
ax1.set_title("Gender Distribution Plot", size=20)
ax1.set_xlabel("Gender", size=15)
ax1.set_ylabel("Count", size=15)
ax1.tick_params(axis='x', labelsize=14)
ax1.tick_params(axis='y', labelsize=14)

ax2 = fig.add_subplot(8,2,2)
bank_df['region'].value_counts().plot(kind='bar')
ax2.set_title("Region Distribution Plot", size=20)
ax2.set_xlabel("Region", size=15)
ax2.set_ylabel("Count", size=15)
ax2.tick_params(axis='x', labelsize=14)
ax2.tick_params(axis='y', labelsize=14)

ax3 = fig.add_subplot(8,2,3)
bank_df['married'].value_counts().plot(kind='bar')
ax3.set_title("Married Distribution Plot", size=20)
ax3.set_xlabel("Married", size=15)
ax3.set_ylabel("Count", size=15)
ax3.tick_params(axis='x', labelsize=14)
ax3.tick_params(axis='y', labelsize=14)

ax4 = fig.add_subplot(8,2,4)
bank_df['car'].value_counts().plot(kind='bar')
ax4.set_title("Car Distribution Plot", size=20)
ax4.set_xlabel("Car", size=15)
ax4.set_ylabel("Count", size=15)
ax4.tick_params(axis='x', labelsize=14)
ax4.tick_params(axis='y', labelsize=14)

ax5 = fig.add_subplot(8,2,5)
bank_df['savings_acct'].value_counts().plot(kind='bar')
ax5.set_title("Savings_acct Distribution Plot", size=20)
ax5.set_xlabel("savings_acct", size=15)
ax5.set_ylabel("Count", size=15)
ax5.tick_params(axis='x', labelsize=14)
ax5.tick_params(axis='y', labelsize=14)

ax6 = fig.add_subplot(8,2,6)
bank_df['current_acct'].value_counts().plot(kind='bar')
ax6.set_title("Current_acct Distribution Plot", size=20)
ax6.set_xlabel("Current_acct", size=15)
ax6.set_ylabel("Count", size=15)
ax6.tick_params(axis='x', labelsize=14)
ax6.tick_params(axis='y', labelsize=14)


ax7 = fig.add_subplot(8,2,7)
bank_df['mortgage'].value_counts().plot(kind='bar')
ax7.set_title("Mortgage Distribution Plot", size=20)
ax7.set_xlabel("Mortgage", size=15)
ax7.set_ylabel("Count", size=15)
ax7.tick_params(axis='x', labelsize=14)
ax7.tick_params(axis='y', labelsize=14)

ax8 = fig.add_subplot(8,2,8)
bank_df['pep'].value_counts().plot(kind='bar')
ax8.set_title("PEP Distribution Plot", size=20)
ax8.set_xlabel("PEP", size=15)
ax8.set_ylabel("Count", size=15)
ax8.tick_params(axis='x', labelsize=14)
ax8.tick_params(axis='y', labelsize=14)


plt.show()

# %%
#The following is the Numerical statistics associated with the Catagical attributes (i.e."gender")
bank_df.groupby('gender').describe()
# Out:
#                      age    children        income
# gender
# FEMALE count  300.000000  300.000000    300.000000
#        mean    43.693333    1.026667  27831.368233
#        std     14.672545    1.078502  13031.258242
#        min     18.000000    0.000000   7549.380000
#        25%     31.000000    0.000000  17711.100000
#        50%     44.000000    1.000000  25448.900000
#        75%     57.000000    2.000000  34873.100000
#        max     67.000000    3.000000  63130.100000
# MALE   count  300.000000  300.000000    300.000000
#        mean    41.096667    0.996667  27216.694200
#        std     14.077924    1.036131  12780.682144
#        min     18.000000    0.000000   5014.210000
#        25%     29.000000    0.000000  16805.175000
#        50%     40.000000    1.000000  24449.200000
#        75%     52.000000    2.000000  36610.850000
#        max     67.000000    3.000000  59409.100000

# %%
#The following is the Numerical statistics associated with the Catagical attributes (i.e."region")
bank_df.groupby('region').describe()
# Out:
#                          age    children        income
# region
# INNER_CITY count  269.000000  269.000000    269.000000
#            mean    41.992565    0.951673  26843.999963
#            std     14.987306    1.019167  13015.863373
#            min     18.000000    0.000000   6294.210000
#            25%     28.000000    0.000000  16352.200000
#            50%     41.000000    1.000000  24262.800000
#            75%     56.000000    2.000000  36166.200000
#            max     67.000000    3.000000  61554.600000
# RURAL      count   96.000000   96.000000     96.000000
#            mean    43.010417    1.229167  30027.605417
#            std     14.396268    1.156029  13699.154297
#            min     18.000000    0.000000   8639.240000
#            25%     31.000000    0.000000  19543.175000
#            50%     44.000000    1.000000  27630.150000
#            75%     55.250000    2.000000  41750.600000
#            max     67.000000    3.000000  57398.100000
# ...

# %%
#The following is the Numerical statistics associated with the Catagical attributes (i.e."married")
bank_df.groupby('married').describe()
# Out:
#                       age    children        income
# married
# NO      count  204.000000  204.000000    204.000000
#         mean    42.186275    1.083333  27674.627108
#         std     14.477590    1.068085  13391.270334
#         min     18.000000    0.000000   5014.210000
#         25%     29.750000    0.000000  16816.000000
#         50%     43.000000    1.000000  25890.650000
#         75%     54.500000    2.000000  36300.875000
#         max     67.000000    3.000000  60747.500000
# YES     count  396.000000  396.000000    396.000000
#         mean    42.502525    0.974747  27446.451515
#         std     14.414918    1.050313  12655.229551
#         min     18.000000    0.000000   7723.930000
#         25%     30.000000    0.000000  17555.250000
#         50%     42.000000    1.000000  24718.250000
#         75%     55.250000    2.000000  36113.475000
#         max     67.000000    3.000000  63130.100000

# %%
#The following is the Numerical statistics associated with the Catagical attributes (i.e."car")
bank_df.groupby('car').describe()
# Out:
#                   age    children        income
# car
# NO  count  304.000000  304.000000    304.000000
#     mean    41.289474    0.973684  26486.807336
#     std     14.488931    1.055849  12973.040522
#     min     18.000000    0.000000   6294.210000
#     25%     28.000000    0.000000  16383.850000
#     50%     41.000000    1.000000  23312.550000
#     75%     53.250000    2.000000  34598.275000
#     max     67.000000    3.000000  61554.600000
# YES count  296.000000  296.000000    296.000000
#     mean    43.530405    1.050676  28589.288176
#     std     14.294449    1.058044  12757.662091
#     min     18.000000    0.000000   5014.210000
#     25%     32.000000    0.000000  18046.675000
#     50%     43.000000    1.000000  26665.200000
#     75%     56.250000    2.000000  36591.500000
#     max     67.000000    3.000000  63130.100000

# %%
#The following is the Numerical statistics associated with the Catagical attributes (i.e."savings_acct")
bank_df.groupby('savings_acct').describe()
# Out:
#                            age    children        income
# savings_acct
# NO           count  186.000000  186.000000    186.000000
#              mean    38.430108    0.946237  22405.999194
#              std     13.309129    1.069130   8151.117426
#              min     18.000000    0.000000   7549.380000
#              25%     27.000000    0.000000  16307.225000
#              50%     37.500000    1.000000  22281.250000
#              75%     48.000000    2.000000  27968.225000
#              max     67.000000    3.000000  39547.800000
# YES          count  414.000000  414.000000    414.000000
#              mean    44.176329    1.041063  29823.436908
#              std     14.566548    1.051117  13945.481952
#              min     18.000000    0.000000   5014.210000
#              25%     32.250000    0.000000  17886.525000
#              50%     45.000000    1.000000  27734.600000
#              75%     57.000000    2.000000  41005.225000
# ...

# %%
#The following is the Numerical statistics associated with the Catagical attributes (i.e."current_acct")
bank_df.groupby('current_acct').describe()
# Out:
#                            age    children        income
# current_acct
# NO           count  145.000000  145.000000    145.000000
#              mean    43.296552    1.000000  26802.195655
#              std     13.741727    1.060660  11841.829836
#              min     18.000000    0.000000   7606.250000
#              25%     32.000000    0.000000  17839.900000
#              50%     42.000000    1.000000  24554.100000
#              75%     57.000000    2.000000  33615.400000
#              max     67.000000    3.000000  57880.700000
# YES          count  455.000000  455.000000    455.000000
#              mean    42.107692    1.015385  27754.066725
#              std     14.638953    1.056647  13222.825776
#              min     18.000000    0.000000   5014.210000
#              25%     29.000000    0.000000  17144.350000
#              50%     42.000000    1.000000  25132.900000
#              75%     54.000000    2.000000  36594.000000
# ...

# %%
#The following is the Numerical statistics associated with the Catagical attributes (i.e."mortgage")
bank_df.groupby('mortgage').describe()
# Out:
#                        age    children        income
# mortgage
# NO       count  391.000000  391.000000    391.000000
#          mean    42.565217    1.069054  27662.194680
#          std     14.461805    1.073140  13199.249366
#          min     18.000000    0.000000   7549.380000
#          25%     30.000000    0.000000  17144.350000
#          50%     43.000000    1.000000  25127.700000
#          75%     54.500000    2.000000  36434.600000
#          max     67.000000    3.000000  63130.100000
# YES      count  209.000000  209.000000    209.000000
#          mean    42.076555    0.904306  27265.553158
#          std     14.384951    1.019252  12345.988391
#          min     18.000000    0.000000   5014.210000
#          25%     31.000000    0.000000  17866.900000
#          50%     41.000000    1.000000  24763.300000
#          75%     56.000000    2.000000  34852.300000
#          max     67.000000    3.000000  60747.500000

# %%
#The following is the Numerical statistics associated with the Catagical attributes (i.e."pep")
bank_df.groupby('pep').describe()
# Out:
#                   age    children        income
# pep
# NO  count  326.000000  326.000000    326.000000
#     mean    40.098160    1.067485  24900.953374
#     std     14.123506    1.195524  11661.123422
#     min     18.000000    0.000000   5014.210000
#     25%     27.000000    0.000000  15366.475000
#     50%     40.000000    0.000000  23105.000000
#     75%     51.000000    2.000000  31210.900000
#     max     67.000000    3.000000  61554.600000
# YES count  274.000000  274.000000    274.000000
#     mean    45.127737    0.945255  30644.919453
#     std     14.327991    0.860571  13609.613043
#     min     18.000000    0.000000   7756.360000
#     25%     34.000000    0.000000  19639.475000
#     50%     45.000000    1.000000  28080.050000
#     75%     58.000000    1.000000  38458.350000
#     max     67.000000    3.000000  63130.100000

# %% [markdown]
# #2) Suppose that because of the bank is particularly interested in customers who buy the PEP (Personal Equity Plan) product. Compare and contrast the subsets of customers who buy and don't buy the PEP. Compute summaries (as in part 1) of the selected data with respect to all other attributes. Can you observe any significant differences between these segments of customers? Discuss your observations.
#
# Ans:
# Based on the above, we could acknowledge that the count of customers purchased PEP ('YES'=274) products are lesser than the customers NOT purchase ('NO'=326).
#
# The mean value of Age and Income of the characteristic of customers shows some differentiation between groups of customers. The Customers that purchase PEP products generally about 5 years older than groups of NOT purchased pep products. Also, The income of the group customers purchase pep has about $5744 higher income than the NOT purchased group. This result is quite consisent, the higher age group normally has higher pay than younger group. And this might be the driving force for the group of customers to purchase the pep product.
#
# For the gender, we could check on the percentage of gender of the group of customers purchase PEP product. The proportion of Female and Male within the group is actually very close. Female takes ONLY 47.45% of the group which means Males takes more than half portion of the group.
#
# Within the group of purchased PEP customers, we could obsviously observe that the majority of customers are from INNER City area. This founding could be another Lead for the bank where they could focus on their marketing stragegy.
#
# Married customers seems about 10% more than the customers are not married within the group. But we should also observe that the Married customers are also dominated within the group of NOT purchased PEP product.
#
# Now, we should look at one of the major difference between the segments of customers. The majority of customers have either Saving or Checking accounts purchases PEP products. Within the purchased group, The customers have Saving accounts almost reach 90% more than the customers have NO saving account. Also, The customers have Checking accounts almost exceed 3 times more than the customers have NO Checking account within the purchased group. I would propose that this happening might be correlated to the income or saving habit.
#
# For the Mortgage, we found out that the customers have NO mortgage almost double the number of customers have mortgage within the purchased group.
#
# The above is the brief summary of the group of customers purchase PEP products. I believe we have to understand more on the detail of the PEP products in order to discover more characteristics of the customers.

# %%
print('Number of of Customers Purchased PEP product: ',sum(bank_df['pep']=='YES'))
print('Number of of Customers NOT Purchased PEP product: ',sum(bank_df['pep']=='NO'))
# Out:
# Number of of Customers Purchased PEP product:  274
# Number of of Customers NOT Purchased PEP product:  326

# %%
bank_df["pep"].value_counts().plot(kind="bar")
plt.title('PEP Product Purchase Chart')
plt.show()

# %%
bank_df.groupby('pep').describe()
# Out:
#                   age    children        income
# pep
# NO  count  326.000000  326.000000    326.000000
#     mean    40.098160    1.067485  24900.953374
#     std     14.123506    1.195524  11661.123422
#     min     18.000000    0.000000   5014.210000
#     25%     27.000000    0.000000  15366.475000
#     50%     40.000000    0.000000  23105.000000
#     75%     51.000000    2.000000  31210.900000
#     max     67.000000    3.000000  61554.600000
# YES count  274.000000  274.000000    274.000000
#     mean    45.127737    0.945255  30644.919453
#     std     14.327991    0.860571  13609.613043
#     min     18.000000    0.000000   7756.360000
#     25%     34.000000    0.000000  19639.475000
#     50%     45.000000    1.000000  28080.050000
#     75%     58.000000    1.000000  38458.350000
#     max     67.000000    3.000000  63130.100000

# %%
cro_pep_gen=pd.crosstab(bank_df['pep'],bank_df['gender'])
cro_pep_gen['%_Female']=cro_pep_gen['FEMALE']/(cro_pep_gen['MALE']+cro_pep_gen['FEMALE'])
print(cro_pep_gen)
cro_pep_gen.plot(kind='bar', figsize=(10,5))
plt.show()
# Out:
# gender  FEMALE  MALE  %_Female
# pep
# NO         170   156  0.521472
# YES        130   144  0.474453

# %%
cro_pep_reg=pd.crosstab(bank_df['pep'],bank_df['region'])
print(cro_pep_reg)
cro_pep_reg.plot(kind='bar', figsize=(10,5))
plt.show()
# Out:
# region  INNER_CITY  RURAL  SUBURBAN  TOWN
# pep
# NO             146     50        28   102
# YES            123     46        34    71

# %%
cro_pep_mar=pd.crosstab(bank_df['pep'],bank_df['married'])
print(cro_pep_mar)
cro_pep_mar.plot(kind='bar', figsize=(10,5))
# Out:
# married   NO  YES
# pep
# NO        84  242
# YES      120  154

# %%
cro_pep_sav=pd.crosstab(bank_df['pep'],bank_df['savings_acct'])
print(cro_pep_sav)
cro_pep_sav.plot(kind='bar',figsize=(10,5))
plt.show()
# Out:
# savings_acct  NO  YES
# pep
# NO            91  235
# YES           95  179

# %%
cro_pep_cur=pd.crosstab(bank_df['pep'],bank_df['current_acct'])
print(cro_pep_cur)
cro_pep_cur.plot(kind='bar',figsize=(10,5))
plt.show()
# Out:
# current_acct  NO  YES
# pep
# NO            82  244
# YES           63  211

# %%
cro_pep_mor=pd.crosstab(bank_df['pep'],bank_df['mortgage'])
print(cro_pep_mor)
cro_pep_mor.plot(kind='bar',figsize=(10,5))
plt.show()
# Out:
# mortgage   NO  YES
# pep
# NO        209  117
# YES       182   92

# %% [markdown]
# #3)Use z-score normalization to standardize the values of the income attribute. [Do not change the original income attribute in the table.]

# %%
z_inc=(bank_df.income-bank_df['income'].mean())/bank_df['income'].std()
z_inc.head(5)
# Out:
# id
# ID12101   -0.773523
# ID12102    0.198541
# ID12103   -0.848766
# ID12104   -0.554180
# ID12105    1.787071
# Name: income, dtype: float64

# %% [markdown]
# #4)Discretize the age attribute into 3 categories (corresponding to "young", "mid-age", and "old"). [Do not change the original age attribute in the table.]

# %%
age_cat=pd.qcut(bank_df['age'],[0,0.33,0.66,1],labels=['young','mid-age','old'])
age_cat.head(10)
# Out:
# id
# ID12101    mid-age
# ID12102    mid-age
# ID12103        old
# ID12104      young
# ID12105        old
# ID12106        old
# ID12107      young
# ID12108        old
# ID12109    mid-age
# ID12110        old
# Name: age, dtype: category
# Categories (3, object): [young < mid-age < old]

# %% [markdown]
# #5)Use Min-Max Normalization to transform the values of all numeric attributes in the original table (income, age, children) onto the range 0.0-1.0.

# %%
bank_df_norm=bank_df[['income','age','children']]
min_max_norm = lambda x: (x-min(x))/(max(x)-min(x))
bank_df_min_max_norm = bank_df_norm.apply(min_max_norm)
bank_df_min_max_norm.head(5)
# Out:
#            income       age  children
# id
# ID12101  0.215634  0.612245  0.333333
# ID12102  0.431395  0.448980  1.000000
# ID12103  0.198933  0.673469  0.000000
# ID12104  0.264320  0.102041  1.000000
# ID12105  0.783987  0.795918  0.000000

# %% [markdown]
# #6) Convert the table (after normalization in part 5) into the standard spreadsheet format. Note that this requires converting each categorical attribute into multiple binary ("dummy") attributes (one for each values of the categorical attribute) and assigning binary values corresponding to the presence or not presence of the attribute value in the original record). Then numeric attributes should remain unchanged. Save this new table into a file called bank_numeric.csv and submitit along with your assignment. [Hint: you might consider using the get_dummies for Pandas data frames.]

# %%
bank_df_dummies=bank_df
bank_df_dummies=bank_dummies= pd.get_dummies(bank_df_dummies, )
bank_df_dummies.head(10)
# Out:
#          age    income  children  gender_FEMALE  gender_MALE  \
# id
# ID12101   48  17546.00         1              1            0
# ID12102   40  30085.10         3              0            1
# ID12103   51  16575.40         0              1            0
# ID12104   23  20375.40         3              1            0
# ID12105   57  50576.30         0              1            0
# ID12106   57  37869.60         2              1            0
# ID12107   22   8877.07         0              0            1
# ID12108   58  24946.60         0              0            1
# ID12109   37  25304.30         2              1            0
# ID12110   54  24212.10         2              0            1
#
#          region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN  \
# id
# ID12101                  1             0                0            0
# ID12102                  0             0                0            1
# ...

# %%
#Check the size of the dataframe match to the original dataframe
bank_df_dummies.shape
# Out:
# (600, 21)

# %%
#Write the dataframe to the CSV file.
bank_df_dummies.to_csv("bank_numeric.csv", float_format='%1.2f')

# %% [markdown]
# #7) Using the standardized data set (of the previous part), perform basic correlation analysis among the attributes. Discuss your results by indicating any significant positive or negative correlations among pairs of attributes. You need to construct a complete Correlation Matrix. Be sure to first remove the Customer ID column before creating the correlation matrix. [Hint: you can do this by using the corr() function in Pandas or corrcoef function in NumPy].
#
# Ans: Based on the following table, we can observe that the attribute of age and income has a positive correlation (0.75) which is the highest correlation among attributes. Based on the data from this table, I would propose that the income is accumulated by experience, Age is actually quite an indicator to show the level of experience has accumulated. Therefore, positive correlation between income and age is reasonable in this case.
#
# Another interesting observation I have got from the table is variables between saving_acct and income, their correlation is not significantly high which is about 27%, but it is worth for us to dicuss a little. The result indicate that the customers with saving accounts is positively correlated with income. This means that the customers have more income having higher chance to have saving accounts. This actually implies that customers might grows a habit to save money if they have higher income. I personally believe that this is a quite a trend happening in this society nowadays.
#
# Besides that, I have NOT found any significantly high correlated factors. The perfectly correlated pair appears on the table would be those from the SAME categorical attributes with binary variables, e.g. correlation between married_NO and married_yes is -1 etc.

# %%
#bank_df_norm_col=bank_df_dummies['income','age','children']
min_max_norm = lambda x: ((x-x.min()) / (x.max()-x.min())) if (x.dtypes==float or x.dtypes == int) else x
bank_df_norm = bank_df_dummies.copy()
bank_df_norm = bank_df_norm.apply(min_max_norm)
bank_df_norm.head(5)
# Out:
#               age    income  children  gender_FEMALE  gender_MALE  \
# id
# ID12101  0.612245  0.215634  0.333333              1            0
# ID12102  0.448980  0.431395  1.000000              0            1
# ID12103  0.673469  0.198933  0.000000              1            0
# ID12104  0.102041  0.264320  1.000000              1            0
# ID12105  0.795918  0.783987  0.000000              1            0
#
#          region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN  \
# id
# ID12101                  1             0                0            0
# ID12102                  0             0                0            1
# ID12103                  1             0                0            0
# ID12104                  0             0                0            1
# ID12105                  0             1                0            0
#
#          married_NO   ...     car_NO  car_YES  savings_acct_NO  \
# id                    ...
# ...

# %%
bank_df_norm.corr()
# Out:
#                         age    income  children  gender_FEMALE  gender_MALE  \
# age                1.000000  0.752726  0.023572       0.090081    -0.090081
# income             0.752726  1.000000  0.036761       0.023845    -0.023845
# children           0.023572  0.036761  1.000000       0.014206    -0.014206
# gender_FEMALE      0.090081  0.023845  0.014206       1.000000    -1.000000
# gender_MALE       -0.090081 -0.023845 -0.014206      -1.000000     1.000000
# region_INNER_CITY -0.025171 -0.047564 -0.051222      -0.023459     0.023459
# region_RURAL       0.018635  0.084776  0.089902      -0.009092     0.009092
# region_SUBURBAN    0.031345  0.029824 -0.014122      -0.010951     0.010951
# region_TOWN       -0.008510 -0.036431 -0.007033       0.040472    -0.040472
# married_NO        -0.010394  0.008386  0.048716       0.021110    -0.021110
# married_YES        0.010394 -0.008386 -0.048716      -0.021110     0.021110
# ...

# %% [markdown]
# #8) Using Matplotlib library and/or ploting capabilties of Pandas, create a scatter plot of the (non-normalized) Income attribute relative to Age. Be sure that your plot contains appropriate labels for the axes. Do these variables seem correlated?

# %%
#Plotting Scatter plot of Income relative to Age
bank_df.plot(y='income', x='age', kind='scatter',title='Income vs Age')
plt.show()

# %% [markdown]
# We could observe that the income is positively correlated to age. In other words, the more income associated with older age based on the given set of data.

# %% [markdown]
# #9.)Create histograms for (non-normalized) Income (using 9 bins) and Age (using 15 bins).

# %%
bank_df['income'].plot(kind='hist', bins=9,title='Income Histogram',color='orange', edgecolor='black')
plt.xlabel('Income')
plt.show()

# %%
bank_df['age'].plot(kind='hist',bins=15,title='Age Histogram', edgecolor='black')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# #10.) Using a bargraph, plot the distribution of the values of the region attribute.

# %%
bank_df['region'].value_counts().plot(kind='bar',title='Region Barplot', color='red',edgecolor='black')
plt.xlabel('Region', size=15)
plt.show()

# %% [markdown]
# #11.)Perform a cross-tabulation of the region attribute with the pep attribute. This requires the aggregation of the occurrences of each pep value (yes or no) separately for each value of the region attribute. Show the results as a 4 by 2 (region x pep) table with entries representing the counts. [Hint: you can either use Numpy or use aggregations fucntions in Pandas such as groupby() and  cross-tab().] Then, either using Matplotlib directly or the plot() function in Pandas create a bar chart graph to visualize of the relationships between these sets of variables. [Hint: This example of creating simple bar charts using Matplotlib may be useful.]

# %%
#Use Groupby function to generate 4x2 table
bank_df.groupby(['region','pep'])['region'].count()
# Out:
# region      pep
# INNER_CITY  NO     146
#             YES    123
# RURAL       NO      50
#             YES     46
# SUBURBAN    NO      28
#             YES     34
# TOWN        NO     102
#             YES     71
# Name: region, dtype: int64

# %%
#Use Crosstab function to generate 4x2 table
cro_pep_reg=pd.crosstab(bank_df['region'],bank_df['pep'])
print(cro_pep_reg)
# Out:
# pep          NO  YES
# region
# INNER_CITY  146  123
# RURAL        50   46
# SUBURBAN     28   34
# TOWN        102   71

# %%
#Plot the Barplot for PEP and Region Catagory attribute
cro_pep_reg.plot(kind='bar', figsize=(10,5))
plt.xlabel('PEP', size=15)
plt.ylabel('Count',size=15)
plt.show()
