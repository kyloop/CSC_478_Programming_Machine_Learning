# %% [markdown]
# ####PCA for Reduced Dimensionality in Clustering [Dataset: segmentation_data.zip]
# For this problem you will use an image segmentation data set for clustering. You will experiment with using PCA as an approach to reduce dimensionality and noise in the data. You will compare the results of clustering the data with and without PCA using the provided image class assignments as the ground truth. The data set is divided into three files. The file "segmentation_data.txt" contains data about images with each line corresponding to one image. Each image is represented by 19 features (these are the columns in the data and correspond to the feature names in the file "segmentation_names.txt". The file "segmentation_classes.txt" contains the class labels (the type of image) and a numeric class label for each of the corresponding images in the data file. After clustering the image data, you will use the class labels to measure completeness and homogeneity of the generated clusters. The data set used in this problem is based on the Image Segmentation data set at the UCI Machine Learning Repository.

# %% [markdown]
# ####1a) Load in the image data matrix (with rows as images and columns as features). Also load in the numeric class labels from the segmentation class file. Using your favorite method (e.g., sklearn's min-max scaler), perform min-max normalization on the data matrix so that each feature is scaled to [0,1] range.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing

# %%
seData=pd.read_csv('./segmentation_data/segmentation_data.txt',header=None)
seClass=pd.read_csv('./segmentation_data/segmentation_classes.txt',sep='\t',header=None)
seName=pd.read_csv('./segmentation_data/segmentation_names.txt',header=None)

# %%
print(seData.shape)
seData.head(5)
# Out:
# (2100, 19)
#       0      1   2    3    4         5         6         7         8   \
# 0  110.0  189.0   9  0.0  0.0  1.000000  0.666667  1.222222  1.186342
# 1   86.0  187.0   9  0.0  0.0  1.111111  0.720082  1.444444  0.750309
# 2  225.0  244.0   9  0.0  0.0  3.388889  2.195113  3.000000  1.520234
# 3   47.0  232.0   9  0.0  0.0  1.277778  1.254621  1.000000  0.894427
# 4   97.0  186.0   9  0.0  0.0  1.166667  0.691215  1.166667  1.005540
#
#           9          10         11         12        13         14         15  \
# 0  12.925926  10.888889   9.222222  18.666668 -6.111111 -11.111111  17.222221
# 1  13.740741  11.666667  10.333334  19.222221 -6.222222 -10.222222  16.444445
# 2  12.259259  10.333334   9.333334  17.111110 -5.777778  -8.777778  14.555555
# 3  12.703704  11.000000   9.000000  18.111110 -5.111111 -11.111111  16.222221
# 4  15.592592  13.888889  11.777778  21.111110 -5.111111 -11.444445  16.555555
#
#           16        17        18
# 0  18.666668  0.508139  1.910864
# 1  19.222221  0.463329  1.941465
# 2  17.111110  0.480149  1.987902
# 3  18.111110  0.500966  1.875362
# 4  21.111110  0.442661  1.863654

# %%
print(seClass.shape)
seClass.head(5)
# Out:
# (2100, 2)
#        0  1
# 0  GRASS  0
# 1  GRASS  0
# 2  GRASS  0
# 3  GRASS  0
# 4  GRASS  0

# %%
print(seName.shape)
seName.head(5)
# Out:
# (19, 1)
#                       0
# 0   REGION-CENTROID-COL
# 1   REGION-CENTROID-ROW
# 2    REGION-PIXEL-COUNT
# 3  SHORT-LINE-DENSITY-5
# 4  SHORT-LINE-DENSITY-2

# %%
np.set_printoptions(precision=2, linewidth=120, suppress=True)

#Use Min_Max function to normalize the data to (0,1) Scale.
min_max_scaler=preprocessing.MinMaxScaler().fit(seData)
scData_norm=min_max_scaler.transform(seData)
print(scData_norm.shape)
scData_norm[0:5]
# Out:
# (2100, 19)
# array([[ 0.43,  0.74,  0.  ,  0.  ,  0.  ,  0.03,  0.  ,  0.03,  0.  ,  0.09,  0.08,  0.06,  0.13,  0.73,  0.01,  0.87,
#          0.12,  0.51,  0.83],
#        [ 0.34,  0.73,  0.  ,  0.  ,  0.  ,  0.04,  0.  ,  0.03,  0.  ,  0.1 ,  0.09,  0.07,  0.13,  0.73,  0.02,  0.86,
#          0.13,  0.46,  0.84],
#        [ 0.89,  0.97,  0.  ,  0.  ,  0.  ,  0.12,  0.  ,  0.07,  0.  ,  0.09,  0.08,  0.06,  0.12,  0.74,  0.04,  0.83,
#          0.11,  0.48,  0.84],
#        [ 0.18,  0.92,  0.  ,  0.  ,  0.  ,  0.04,  0.  ,  0.02,  0.  ,  0.09,  0.08,  0.06,  0.13,  0.75,  0.01,  0.86,
#          0.12,  0.5 ,  0.83],
#        [ 0.38,  0.73,  0.  ,  0.  ,  0.  ,  0.04,  0.  ,  0.03,  0.  ,  0.11,  0.1 ,  0.08,  0.15,  0.75,  0.01,  0.86,
#          0.14,  0.44,  0.82]])

# %% [markdown]
# ####1b) Next, Perform Kmeans clustering (for this problem, use the Kmeans implementation in scikit-learn) on the image data (since there are a total 7 pre-assigned image classes, you should use K = 7 in your clustering). Use Euclidean distance as your distance measure for the clustering. Print the cluster centroids (use some formatting so that they are visually understandable). Compare your 7 clusters to the 7 pre-assigned classes by computing the Completeness and Homogeneity values of the generated clusters.

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=7,max_iter=500,verbose=1) #initialize clusters parameters
#Plug in the normalized data into the 
kmeans.fit(scData_norm)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 422.148596285
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 396.994995473
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 391.819994747
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 387.729886358
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 382.326221358
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 375.311176533
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 371.580994732
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 370.887452334
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 370.759093143
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 370.673169002
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 370.639209634
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 370.634115984
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 370.632975691
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 370.630860259
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 370.630860259
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 399.578145499
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 385.657191653
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 375.33095352
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 369.290564041
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 368.052291127
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 367.816833924
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 367.674511435
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 367.635482611
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 367.615065999
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 367.586102147
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 367.579049744
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 367.570564901
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 367.562156952
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 367.560523222
# center shift 1.826740e-03 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 415.719099545
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 405.602049871
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 403.857088081
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 402.456453397
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 401.802561411
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 401.442446994
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 401.165350307
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 401.056143325
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 401.001977575
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 400.909852929
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 400.777279667
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 400.766155678
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 400.748887343
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 400.697574887
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 400.544298695
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 400.228792891
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 399.690052877
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 399.001231135
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 398.502898218
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 398.235538789
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 398.147927036
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 398.130420747
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 398.099231263
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 398.074321944
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 398.028674719
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 398.013007297
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 398.00703039
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 398.004352808
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 398.004352808
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 450.76545842
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 392.998724674
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 377.354244818
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 374.489739105
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 373.853961742
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 373.716232503
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 373.667239621
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 373.642181762
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 373.63338852
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 373.631737418
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 373.631737418
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 419.434182157
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 381.309594389
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 377.784767014
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 375.885008386
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 375.295175163
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 374.995639394
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 374.804459467
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 374.669502377
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 374.612190335
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 374.52686859
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 374.435396163
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 374.305179112
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 374.100761422
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 373.970799813
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 373.911295224
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 373.868503478
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 373.818116463
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 373.774289412
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 373.742426837
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 373.706314735
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 373.682618101
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 373.662827808
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 373.616920808
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 373.613274209
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 373.613274209
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 375.134291107
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 352.887195231
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 350.604347459
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 350.112686507
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 350.043806022
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 350.016216344
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 350.014297011
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 350.012902719
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 350.012902719
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 394.444062466
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 370.115869011
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 367.227126758
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 364.692899366
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 364.060126632
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 363.258462308
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 360.504312651
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 354.272366462
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 351.380463933
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 350.346617114
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 350.082533253
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 350.027828632
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 350.012079741
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 350.012079741
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 452.945079383
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 422.464949846
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 412.620256579
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 403.467993513
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 396.022443619
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 390.129252289
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 387.705284133
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 386.221684217
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 385.010260861
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 382.911233497
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 380.534258771
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 378.59037556
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 377.773760898
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 377.162153899
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 376.871738889
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 376.685603237
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 376.564048815
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 376.427939698
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 376.329426595
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 376.241472898
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 376.159292819
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 376.04543431
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 376.002436074
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 375.977798576
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 375.949574826
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 375.904232596
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 375.872450158
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 375.853939552
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 375.842612964
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 375.842612964
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 427.882199388
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 389.82779729
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 379.117412963
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 376.627301511
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 376.235896695
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 376.189977954
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 376.169669957
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 376.16158125
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 376.133820968
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 376.11794854
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 376.113644381
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 376.111539832
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 376.102735527
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 376.100392425
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 376.100392425
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 413.092997515
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 366.890954099
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 354.038044326
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 351.017661702
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 350.298022753
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 350.116824673
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 350.030960141
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 350.012079741
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 350.012079741
# center shift 0.000000e+00 within tolerance 4.150157e-06
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=500,
#     n_clusters=7, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=1)

# %%
#Predict the data points falling into the Clusters
clusters=kmeans.predict(scData_norm)
clusters
# Out:
# array([4, 4, 4, ..., 1, 1, 3], dtype=int32)

# %%
clusters.shape
# Out:
# (2100,)

# %%
a=seName.T
c=kmeans.cluster_centers_
ac=np.concatenate([a,c]) #Concatenate the clusters centers coordinates and attribute names

# %%
c
# Out:
# array([[ 0.3 ,  0.53,  0.  ,  0.05,  0.05,  0.1 ,  0.01,  0.08,  0.01,  0.4 ,  0.37,  0.47,  0.35,  0.5 ,  0.57,  0.21,
#          0.47,  0.3 ,  0.16],
#        [ 0.77,  0.43,  0.  ,  0.01,  0.02,  0.04,  0.  ,  0.02,  0.  ,  0.04,  0.04,  0.06,  0.03,  0.78,  0.22,  0.49,
#          0.06,  0.54,  0.24],
#        [ 0.54,  0.15,  0.  ,  0.03,  0.  ,  0.03,  0.  ,  0.03,  0.  ,  0.82,  0.78,  0.89,  0.79,  0.27,  0.67,  0.29,
#          0.89,  0.21,  0.13],
#        [ 0.26,  0.39,  0.  ,  0.07,  0.02,  0.08,  0.  ,  0.06,  0.  ,  0.15,  0.14,  0.19,  0.12,  0.72,  0.34,  0.36,
#          0.19,  0.41,  0.2 ],
#        [ 0.51,  0.81,  0.  ,  0.08,  0.01,  0.05,  0.  ,  0.05,  0.  ,  0.11,  0.09,  0.09,  0.14,  0.68,  0.08,  0.82,
#          0.13,  0.41,  0.89],
#        [ 0.75,  0.53,  0.  ,  0.04,  0.04,  0.11,  0.02,  0.11,  0.02,  0.3 ,  0.28,  0.35,  0.27,  0.59,  0.45,  0.31,
#          0.35,  0.3 ,  0.16],
#        [ 0.25,  0.46,  0.  ,  0.03,  0.01,  0.04,  0.  ,  0.03,  0.  ,  0.03,  0.02,  0.04,  0.02,  0.77,  0.22,  0.51,
#          0.04,  0.8 ,  0.18]])

# %%
#Show the Centroid of the 7 Clusters
pd.DataFrame(ac[1:].T, index=ac[0])
# Out:
#                                0           1            2           3  \
# REGION-CENTROID-COL     0.302506    0.770674     0.535099    0.256103
# REGION-CENTROID-ROW     0.530862    0.425215     0.150167    0.393468
# REGION-PIXEL-COUNT             0           0            0           0
# SHORT-LINE-DENSITY-5   0.0522599   0.0139785    0.0277778   0.0745098
# SHORT-LINE-DENSITY-2   0.0466102   0.0225806   0.00166667   0.0191176
# VEDGE-MEAN              0.100817   0.0402367    0.0302281   0.0773429
# VEDGE-SD              0.00942022  0.00298876  0.000542888  0.00410042
# HEDGE-MEAN              0.083972   0.0231216     0.026766   0.0605736
# HEDGE-SD               0.0110433   0.0020884  0.000586662  0.00496749
# INTENSITY-MEAN          0.400608   0.0411384     0.823246    0.148187
# RAWRED-MEAN             0.370347   0.0350055     0.779716    0.138085
# RAWBLUE-MEAN            0.472461   0.0583401      0.89417     0.18516
# RAWGREEN-MEAN           0.353036   0.0287657     0.788761    0.118539
# EXRED-MEAN              0.497146    0.778473     0.270665    0.716906
# EXBLUE-MEAN             0.570882    0.223939     0.666373    0.344014
# EXGREEN-MEAN            0.213054    0.486509     0.289386    0.355458
# VALUE-MEAN              0.472461    0.059295      0.89417    0.185413
# SATURATION-MEAN         0.302263    0.538181     0.211804    0.411986
# HUE-MEAN                0.163879    0.243969     0.125066     0.20189
#
#                                4          5           6
# REGION-CENTROID-COL     0.513994   0.750696    0.254169
# REGION-CENTROID-ROW     0.808937   0.534564    0.459974
# REGION-PIXEL-COUNT             0          0           0
# SHORT-LINE-DENSITY-5   0.0774411       0.04   0.0262557
# SHORT-LINE-DENSITY-2  0.00505051  0.0384615   0.0136986
# VEDGE-MEAN             0.0544738   0.114419   0.0372741
# VEDGE-SD              0.00140719  0.0193006  0.00236373
# HEDGE-MEAN              0.046335    0.10924   0.0278737
# HEDGE-SD              0.00140097  0.0179989  0.00201698
# INTENSITY-MEAN           0.10879   0.300955   0.0260125
# RAWRED-MEAN             0.091403   0.279908   0.0179253
# RAWBLUE-MEAN           0.0924141   0.352738   0.0423064
# RAWGREEN-MEAN           0.142676    0.26592    0.016504
# EXRED-MEAN              0.679161   0.592572      0.7698
# EXBLUE-MEAN            0.0790018   0.451124    0.216011
# EXGREEN-MEAN            0.821287   0.309158    0.508117
# VALUE-MEAN              0.134901   0.352822   0.0432949
# SATURATION-MEAN         0.414491   0.302342    0.801687
# HUE-MEAN                0.892333   0.164764    0.181153

# %%
from sklearn.metrics import completeness_score, homogeneity_score

#Compute the Completness Score and Homogeneity Score
print('Completness Score is',completeness_score(clusters,np.array(seClass[1])))
print('Homogeneity Score is ',homogeneity_score(clusters, np.array(seClass[1])))
# Out:
# Completness Score is 0.611502116337
# Homogeneity Score is  0.613187012485

# %% [markdown]
# The Completness Score and Homogeneity Score are not very high score, but their values are very balance which is also a good sign for the analysis.

# %% [markdown]
# ####2c) Perform PCA on the normalized image data matrix. You may use the linear algebra package in Numpy or the Decomposition module in scikit-learn (the latter is much more efficient). Analyze the principal components to determine the number, r, of PCs needed to capture at least 95% of variance in the data. Then use these r components as features to transform the data into a reduced dimension space. [See the PCA Clustering Notebook from class for an example of how these steps are performed.]

# %%
#import decomposition function from skilearn for PCA analysis
from sklearn import decomposition

# %%
#Set the PCA to the first 7 components
n_items=7
pca=decomposition.PCA(n_components=n_items)
scData_norm_TD=pca.fit(scData_norm).transform(scData_norm)

# %%
print(scData_norm_TD.shape)
# Out:
# (2100, 7)

# %%
np.set_printoptions(precision=2, linewidth=120, suppress=True)

#Let's check the explained Varanice presented by the first 7 components
print(pca.explained_variance_ratio_)
#sum(pca.explained_variance_ratio_)
print('''The first %d components capture %0.2f percent of variance in the data''' %(n_items,sum(pca.explained_variance_ratio_)*100))
# Out:
# [ 0.61  0.13  0.1   0.05  0.04  0.02  0.02]
# The first 7 components capture 96.01 percent of variance in the data

# %%
#Display the transformed 7 components from the original dataset
scData_norm_TD[0:5]
# Out:
# array([[-0.69,  0.53,  0.25, -0.2 , -0.08,  0.05, -0.05],
#        [-0.67,  0.51,  0.34, -0.17, -0.04,  0.06, -0.04],
#        [-0.71,  0.77, -0.16, -0.01, -0.17,  0.04, -0.06],
#        [-0.73,  0.51,  0.5 , -0.06, -0.14,  0.03, -0.1 ],
#        [-0.64,  0.53,  0.3 , -0.18, -0.02,  0.05, -0.06]])

# %% [markdown]
# ####1d) Perform Kmeans again, but this time on the lower dimensional transformed data. Then, compute the Completeness and Homogeneity values of the new clusters.

# %%
kmeans.fit(scData_norm_TD)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 344.791210072
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 333.661757566
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 331.015720231
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 329.811354999
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 328.879968132
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 328.266231846
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 328.042568558
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 327.978412564
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 327.919118519
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 327.883068487
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 327.814552919
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 327.69357173
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 327.572180418
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 327.450127794
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 327.223393773
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 326.724279741
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 326.066199544
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 325.45933133
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 325.12941705
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 324.924334198
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 324.795466569
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 324.760557125
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 324.736994904
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 324.7158713
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 324.711409157
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 324.708008901
# center shift 2.901345e-03 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 335.539420503
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 323.744952247
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 314.606393665
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 311.292909046
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 310.307584438
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 310.093798651
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 309.968048427
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 309.834789352
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 309.757448105
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 309.689075542
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 309.582257908
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 309.351895649
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 309.022726834
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 308.650416872
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 308.177530039
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 307.807365163
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 307.568591916
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 307.491776658
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 307.452636464
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 307.424911474
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 307.418267916
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 307.412265706
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 307.399751577
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 307.388728172
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 307.363773399
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 307.347714088
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 307.347714088
# center shift 0.000000e+00 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 327.424673652
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 304.575414666
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 301.380566479
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 300.850360866
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 300.362554791
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 299.057087086
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 298.071890928
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 294.649622939
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 292.18711325
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 290.633545693
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 289.715199732
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 288.509847796
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 287.820527681
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 287.494583764
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 287.117877149
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 286.684797431
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 286.480544869
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 286.442029611
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 286.442029611
# center shift 0.000000e+00 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 313.045953822
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 298.72974029
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 294.910153204
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 291.923896884
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 289.697115959
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 287.948810728
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 287.104539973
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 286.686944726
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 286.55553293
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 286.481116492
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 286.441758015
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 286.441758015
# center shift 0.000000e+00 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 334.322092641
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 316.055459829
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 311.292225713
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 309.005725727
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 308.55758986
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 308.269473403
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 307.66770275
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 307.31234703
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 306.605721673
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 304.95985355
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 304.522158809
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 304.247909955
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 303.903060447
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 303.314481182
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 302.914303925
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 302.746895833
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 302.711444953
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 302.708025214
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 302.708025214
# center shift 0.000000e+00 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 343.188653948
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 331.073455426
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 326.327249059
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 321.75354747
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 315.292430971
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 310.437756711
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 307.752435412
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 306.864441928
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 306.586470818
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 306.387765965
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 306.374055299
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 306.372321913
# center shift 1.861150e-03 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 297.888112123
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 288.402667383
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 287.057759351
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 286.780927348
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 286.658508534
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 286.46826336
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 286.449035552
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 286.444267055
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 286.443067037
# center shift 2.683138e-03 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 353.540420032
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 339.902993158
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 334.74670766
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 327.863804487
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 320.926560895
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 317.958871815
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 316.54017609
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 315.703592176
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 314.545078871
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 313.417268114
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 311.736003372
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 310.448033676
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 309.426663269
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 308.52746527
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 307.93568216
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 307.610009473
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 307.52265344
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 307.460642208
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 307.421395639
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 307.407552661
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 307.396964381
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 307.368429581
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 307.347623922
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 307.347623922
# center shift 0.000000e+00 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 331.176147805
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 308.838948437
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 303.497892432
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 302.931709636
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 302.850728823
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 302.827814434
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 302.805120901
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 302.800557654
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 302.786834069
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 302.779735648
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 302.779735648
# center shift 0.000000e+00 within tolerance 1.081479e-05
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 346.431033265
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 326.622703065
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 318.424299953
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 314.144763282
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 312.382783042
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 312.014310087
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 311.969619203
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 311.952643879
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 311.952643879
# center shift 0.000000e+00 within tolerance 1.081479e-05
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=500,
#     n_clusters=7, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=1)

# %%
clusters=kmeans.predict(scData_norm_TD)
clusters
# Out:
# array([3, 3, 3, ..., 0, 0, 4], dtype=int32)

# %%
#Compute the Completness Score and Homogeneity Score
print('Completness Score is',completeness_score(clusters,np.array(seClass[1])))
print('Homogeneity Score is ',homogeneity_score(clusters, np.array(seClass[1])))
# Out:
# Completness Score is 0.609136404973
# Homogeneity Score is  0.610795506369

# %% [markdown]
# ####1e) Discuss your observations based on the comparison of the two clustering results.

# %% [markdown]
# The Completness Score and Homogeneity Score of decomposited (PCA processed) which are very similar to the scores of the original dataset are around 0.6 and 0.61. In this case, we could consider to utilize the decomposted model to evaluate the future same structure dataset due to saving computational cost and resources with less components from PCA.

# %%
import apriori2 as ap
