# %% [markdown]
# ####PCA for Reduced Dimensionality in Clustering [Dataset: segmentation_data.zip]
# For this problem you will use an image segmentation data set for clustering. You will experiment with using PCA as an approach to reduce dimensionality and noise in the data. You will compare the results of clustering the data with and without PCA using the provided image class assignments as the ground truth. The data set is divided into three files. The file "segmentation_data.txt" contains data about images with each line corresponding to one image. Each image is represented by 19 features (these are the columns in the data and correspond to the feature names in the file "segmentation_names.txt". The file "segmentation_classes.txt" contains the class labels (the type of image) and a numeric class label for each of the corresponding images in the data file. After clustering the image data, you will use the class labels to measure completeness and homogeneity of the generated clusters. The data set used in this problem is based on the Image Segmentation data set at the UCI Machine Learning Repository.

# %% [markdown]
# ####1a) Load in the image data matrix (with rows as images and columns as features). Also load in the numeric class labels from the segmentation class file. Using your favorite method (e.g., sklearn's min-max scaler), perform min-max normalization on the data matrix so that each feature is scaled to [0,1] range.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing

# %%
seData=pd.read_csv('./segmentation_data/segmentation_data.txt',header=None)
seClass=pd.read_csv('./segmentation_data/segmentation_classes.txt',sep='\t',header=None)
seName=pd.read_csv('./segmentation_data/segmentation_names.txt',header=None)

# %%
print(seData.shape)
seData.head(5)
# Out:
# (2100, 19)
#       0      1   2    3    4         5         6         7         8   \
# 0  110.0  189.0   9  0.0  0.0  1.000000  0.666667  1.222222  1.186342
# 1   86.0  187.0   9  0.0  0.0  1.111111  0.720082  1.444444  0.750309
# 2  225.0  244.0   9  0.0  0.0  3.388889  2.195113  3.000000  1.520234
# 3   47.0  232.0   9  0.0  0.0  1.277778  1.254621  1.000000  0.894427
# 4   97.0  186.0   9  0.0  0.0  1.166667  0.691215  1.166667  1.005540
#
#           9          10         11         12        13         14         15  \
# 0  12.925926  10.888889   9.222222  18.666668 -6.111111 -11.111111  17.222221
# 1  13.740741  11.666667  10.333334  19.222221 -6.222222 -10.222222  16.444445
# 2  12.259259  10.333334   9.333334  17.111110 -5.777778  -8.777778  14.555555
# 3  12.703704  11.000000   9.000000  18.111110 -5.111111 -11.111111  16.222221
# 4  15.592592  13.888889  11.777778  21.111110 -5.111111 -11.444445  16.555555
#
#           16        17        18
# 0  18.666668  0.508139  1.910864
# 1  19.222221  0.463329  1.941465
# 2  17.111110  0.480149  1.987902
# 3  18.111110  0.500966  1.875362
# 4  21.111110  0.442661  1.863654

# %%
print(seClass.shape)
seClass.head(5)
# Out:
# (2100, 2)
#        0  1
# 0  GRASS  0
# 1  GRASS  0
# 2  GRASS  0
# 3  GRASS  0
# 4  GRASS  0

# %%
print(seName.shape)
seName.head(5)
# Out:
# (19, 1)
#                       0
# 0   REGION-CENTROID-COL
# 1   REGION-CENTROID-ROW
# 2    REGION-PIXEL-COUNT
# 3  SHORT-LINE-DENSITY-5
# 4  SHORT-LINE-DENSITY-2

# %%
np.set_printoptions(precision=2, linewidth=120, suppress=True)

#Use Min_Max function to normalize the data to (0,1) Scale.
min_max_scaler=preprocessing.MinMaxScaler().fit(seData)
scData_norm=min_max_scaler.transform(seData)
print(scData_norm.shape)
scData_norm[0:5]
# Out:
# (2100, 19)
# array([[ 0.43,  0.74,  0.  ,  0.  ,  0.  ,  0.03,  0.  ,  0.03,  0.  ,  0.09,  0.08,  0.06,  0.13,  0.73,  0.01,  0.87,
#          0.12,  0.51,  0.83],
#        [ 0.34,  0.73,  0.  ,  0.  ,  0.  ,  0.04,  0.  ,  0.03,  0.  ,  0.1 ,  0.09,  0.07,  0.13,  0.73,  0.02,  0.86,
#          0.13,  0.46,  0.84],
#        [ 0.89,  0.97,  0.  ,  0.  ,  0.  ,  0.12,  0.  ,  0.07,  0.  ,  0.09,  0.08,  0.06,  0.12,  0.74,  0.04,  0.83,
#          0.11,  0.48,  0.84],
#        [ 0.18,  0.92,  0.  ,  0.  ,  0.  ,  0.04,  0.  ,  0.02,  0.  ,  0.09,  0.08,  0.06,  0.13,  0.75,  0.01,  0.86,
#          0.12,  0.5 ,  0.83],
#        [ 0.38,  0.73,  0.  ,  0.  ,  0.  ,  0.04,  0.  ,  0.03,  0.  ,  0.11,  0.1 ,  0.08,  0.15,  0.75,  0.01,  0.86,
#          0.14,  0.44,  0.82]])

# %% [markdown]
# ####1b) Next, Perform Kmeans clustering (for this problem, use the Kmeans implementation in scikit-learn) on the image data (since there are a total 7 pre-assigned image classes, you should use K = 7 in your clustering). Use Euclidean distance as your distance measure for the clustering. Print the cluster centroids (use some formatting so that they are visually understandable). Compare your 7 clusters to the 7 pre-assigned classes by computing the Completeness and Homogeneity values of the generated clusters.

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=7,max_iter=500,verbose=1) #initialize clusters parameters

# %%
kmeans.fit(scData_norm)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 395.5731939
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 373.054526929
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 370.703204752
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 369.903944657
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 369.710605028
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 369.654450949
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 369.648618323
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 369.646726618
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 369.644171171
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 369.644171171
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 364.000927367
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 353.677367997
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 351.450243568
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 351.077234815
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 350.63716344
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 350.149858249
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 350.041876162
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 350.026831095
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 350.020259609
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 350.015959842
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 350.012902719
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 350.012902719
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 401.746450526
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 387.25758794
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 382.467390918
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 376.095389971
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 372.430187762
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 371.249100687
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 370.755063818
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 370.641939043
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 370.619385652
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 370.613903157
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 370.613903157
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 386.930577986
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 360.564879698
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 352.426393107
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 350.672964606
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 350.226743626
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 350.089261584
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 350.04475102
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 350.011574792
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 350.011574792
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 391.945324939
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 364.926930189
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 354.665607167
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 352.2322693
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 351.523083244
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 351.414557486
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 351.343838429
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 351.317661685
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 351.294810269
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 351.251257323
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 351.207435269
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 351.07031065
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 350.798724083
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 350.287368174
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 350.058039669
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 350.030026481
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 350.02504147
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 350.017354133
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 350.012902719
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 350.012902719
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 404.576137015
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 387.651706595
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 382.271500413
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 378.275606042
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 372.084967895
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 366.172386657
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 361.540747338
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 358.542191817
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 356.448360666
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 354.749322218
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 353.77468076
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 352.805372177
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 351.671752554
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 351.369550036
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 351.329340333
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 351.306430798
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 351.283434957
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 351.248941608
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 351.199452329
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 351.051571383
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 350.739752151
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 350.229371223
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 350.058039669
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 350.030026481
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 350.02504147
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 350.017354133
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 350.012902719
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 350.012902719
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 403.348280831
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 396.276843018
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 393.214111912
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 389.520675756
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 385.264422081
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 381.708530501
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 378.541285236
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 372.207332317
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 370.51370397
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 370.368458602
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 370.324619189
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 370.311230646
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 370.30839397
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 370.30839397
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 375.387689892
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 357.005749913
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 352.819283492
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 351.738568135
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 351.375558617
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 351.330642281
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 351.313243887
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 351.295941324
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 351.252739469
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 351.20992911
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 351.085903906
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 350.848218196
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 350.355547102
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 350.069592646
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 350.030026481
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 350.02504147
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 350.017354133
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 350.012902719
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 350.012902719
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 407.305704837
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 376.83938225
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 375.326654327
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 374.953829797
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 374.769171452
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 374.696382823
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 374.606777006
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 374.500847753
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 374.489939998
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 374.489939998
# center shift 0.000000e+00 within tolerance 4.150157e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 428.485232608
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 407.002913005
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 401.16341963
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 396.322813784
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 394.819516438
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 392.42242501
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 387.815528471
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 374.385699905
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 369.709605848
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 368.554695107
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 368.148657074
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 367.878929863
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 367.49404442
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 366.6692199
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 365.777417451
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 365.627344197
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 365.586655798
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 365.57478884
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 365.561180342
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 365.559063681
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 365.540362144
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 365.509121367
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 365.505194172
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 365.503679752
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 365.496061507
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 365.496061507
# center shift 0.000000e+00 within tolerance 4.150157e-06
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=500,
#     n_clusters=7, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=1)

# %%
clusters=kmeans.predict(scData_norm)

# %%
clusters.shape
# Out:
# (2100,)

# %%
a=seName.T
c=kmeans.cluster_centers_
ac=np.concatenate([a,c])

# %%
c
# Out:
# array([[ 0.51,  0.81,  0.  ,  0.08,  0.01,  0.05,  0.  ,  0.05,  0.  ,  0.11,  0.09,  0.09,  0.14,  0.68,  0.08,  0.82,
#          0.13,  0.41,  0.89],
#        [ 0.25,  0.39,  0.  ,  0.08,  0.02,  0.08,  0.  ,  0.06,  0.01,  0.15,  0.14,  0.18,  0.12,  0.72,  0.34,  0.35,
#          0.18,  0.41,  0.2 ],
#        [ 0.54,  0.15,  0.  ,  0.03,  0.  ,  0.03,  0.  ,  0.03,  0.  ,  0.82,  0.78,  0.89,  0.79,  0.27,  0.67,  0.29,
#          0.89,  0.21,  0.13],
#        [ 0.75,  0.53,  0.  ,  0.04,  0.04,  0.11,  0.02,  0.11,  0.02,  0.3 ,  0.28,  0.35,  0.26,  0.59,  0.45,  0.31,
#          0.35,  0.3 ,  0.16],
#        [ 0.25,  0.46,  0.  ,  0.03,  0.01,  0.04,  0.  ,  0.03,  0.  ,  0.03,  0.02,  0.04,  0.02,  0.77,  0.22,  0.51,
#          0.04,  0.8 ,  0.18],
#        [ 0.3 ,  0.53,  0.  ,  0.05,  0.05,  0.1 ,  0.01,  0.08,  0.01,  0.4 ,  0.37,  0.47,  0.35,  0.5 ,  0.57,  0.21,
#          0.47,  0.3 ,  0.16],
#        [ 0.77,  0.43,  0.  ,  0.01,  0.02,  0.04,  0.  ,  0.02,  0.  ,  0.04,  0.03,  0.06,  0.03,  0.78,  0.22,  0.49,
#          0.06,  0.54,  0.24]])

# %%
#Show the Centroid of the 7 Clusters
pd.DataFrame(ac[1:].T, index=ac[0])
# Out:
#                                0           1            2          3  \
# REGION-CENTROID-COL     0.513994    0.251678     0.535099   0.748274
# REGION-CENTROID-ROW     0.808937    0.392749     0.150167   0.532041
# REGION-PIXEL-COUNT             0           0            0          0
# SHORT-LINE-DENSITY-5   0.0774411   0.0756219    0.0277778  0.0391566
# SHORT-LINE-DENSITY-2  0.00505051    0.019403   0.00166667  0.0376506
# VEDGE-MEAN             0.0544738   0.0776573    0.0302281    0.11353
# VEDGE-SD              0.00140719  0.00414943  0.000542888  0.0189224
# HEDGE-MEAN              0.046335   0.0612404     0.026766   0.107311
# HEDGE-SD              0.00140097  0.00503684  0.000586662   0.017627
# INTENSITY-MEAN           0.10879    0.147428     0.823246   0.298573
# RAWRED-MEAN             0.091403    0.137485     0.779716   0.277521
# RAWBLUE-MEAN           0.0924141    0.184391      0.89417   0.350081
# RAWGREEN-MEAN           0.142676    0.117637     0.788761   0.263837
# EXRED-MEAN              0.679161     0.71825     0.270665     0.5933
# EXBLUE-MEAN            0.0790018    0.343789     0.666373   0.449242
# EXGREEN-MEAN            0.821287    0.354454     0.289386   0.311453
# VALUE-MEAN              0.134901    0.184648      0.89417   0.350163
# SATURATION-MEAN         0.414491    0.413414     0.211804   0.303047
# HUE-MEAN                0.892333    0.202752     0.125066   0.164359
#
#                                4           5           6
# REGION-CENTROID-COL     0.253603    0.302506    0.769063
# REGION-CENTROID-ROW     0.459865    0.530862     0.42593
# REGION-PIXEL-COUNT             0           0           0
# SHORT-LINE-DENSITY-5   0.0263459   0.0522599   0.0140237
# SHORT-LINE-DENSITY-2   0.0137457   0.0466102   0.0226537
# VEDGE-MEAN             0.0373368    0.100817   0.0397025
# VEDGE-SD               0.0023699  0.00942022  0.00298261
# HEDGE-MEAN             0.0279012    0.083972    0.023116
# HEDGE-SD              0.00202174   0.0110433  0.00209423
# INTENSITY-MEAN         0.0259422    0.400608    0.040385
# RAWRED-MEAN            0.0177753    0.370347   0.0344264
# RAWBLUE-MEAN           0.0422797    0.472461    0.057385
# RAWGREEN-MEAN          0.0164643    0.353036   0.0280592
# EXRED-MEAN              0.769272    0.497146    0.779917
# EXBLUE-MEAN             0.216204    0.570882    0.222795
# EXGREEN-MEAN            0.508343    0.213054    0.486886
# VALUE-MEAN             0.0432514    0.472461    0.058362
# SATURATION-MEAN         0.802618    0.302263    0.539152
# HUE-MEAN                0.180506    0.163879    0.244988

# %% [markdown]
# ####2c) Perform PCA on the normalized image data matrix. You may use the linear algebra package in Numpy or the Decomposition module in scikit-learn (the latter is much more efficient). Analyze the principal components to determine the number, r, of PCs needed to capture at least 95% of variance in the data. Then use these r components as features to transform the data into a reduced dimension space. [See the PCA Clustering Notebook from class for an example of how these steps are performed.]
